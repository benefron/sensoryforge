# %% [markdown]
# # SensoryForge Quickstart
#
# This notebook builds one receptor grid, two neuron populations (SA and RA), drives them with a
# Gaussian pressure bump, and plots the resulting spike rasters -- the same canonical
# `SensoryForgeConfig` / `SimulationEngine` path used by the CLI (`sensoryforge run`) and the GUI.
#
# **What you'll learn:**
# - Building a canonical `SensoryForgeConfig` (grid + SA/RA populations) in Python
# - Generating a spatial stimulus and running it through `SimulationEngine`
# - Reading the result dict and plotting a spike raster
#
# **CI note:** this notebook runs with a small grid and few neurons so it executes in well under two
# minutes in CI (`pytest --nbmake docs/examples`, see `tests/docs/`). The committed cell outputs
# below come from exactly this reduced size, run locally with `jupyter nbconvert --execute` -- there
# is no larger "full" version whose numbers these outputs are a stand-in for; scale `rows`/`cols` and
# `neurons_per_row` up for your own exploration (see `examples/canonical_config.yml` for an
# 80x80-grid-sized configuration).

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import torch

from sensoryforge.config.schema import (
    GridConfig,
    PopulationConfig,
    SensoryForgeConfig,
    SimulationConfig,
)
from sensoryforge.core.simulation_engine import SimulationEngine
from sensoryforge.stimuli.stimulus import gaussian_pressure_torch

torch.manual_seed(0)
device = "cpu"

# %% [markdown]
# ## Step 1: Build the canonical config
#
# One 24x24 receptor grid (0.15 mm spacing), an SA population (6x6 = 36 neurons) and an RA
# population (8x8 = 64 neurons), both innervated by `gaussian` receptive fields. `input_gain=50.0`
# compensates the SA/RA filter's calibrated units against SensoryForge's mA stimulus amplitude (see
# `docs/user_guide/units_and_gains.md` -- do not drop this when adapting the config).

# %%
grid = GridConfig(
    name="Main Grid",
    arrangement="grid",
    rows=24,
    cols=24,
    spacing=0.15,
)

sa_population = PopulationConfig(
    name="SA Population",
    neuron_type="SA",
    target_grid="Main Grid",
    innervation_method="gaussian",
    connections_per_neuron=20,
    sigma_d_mm=0.3,
    neurons_per_row=6,
    neuron_model="izhikevich",
    filter_method="sa",
    input_gain=50.0,
)

ra_population = PopulationConfig(
    name="RA Population",
    neuron_type="RA",
    target_grid="Main Grid",
    innervation_method="gaussian",
    connections_per_neuron=20,
    sigma_d_mm=0.3,
    neurons_per_row=8,
    neuron_model="izhikevich",
    filter_method="ra",
    input_gain=50.0,
)

config = SensoryForgeConfig(
    grids=[grid],
    populations=[sa_population, ra_population],
    simulation=SimulationConfig(device=device, dt_ms=1.0),
)

engine = SimulationEngine(config)
print(f"Populations: {[p.name for p in config.populations]}")
# Out:
# Populations: ['SA Population', 'RA Population']

# %% [markdown]
# ## Step 2: Generate a stimulus
#
# A Gaussian pressure bump at the grid centre, ramped up, held, and ramped back down over 80 ms
# (`dt_ms=1.0`, so 80 frames).

# %%
rows, cols = grid.rows, grid.cols
half_extent = (rows - 1) * grid.spacing / 2.0
coords_1d = torch.linspace(-half_extent, half_extent, rows)
xx, yy = torch.meshgrid(coords_1d, coords_1d, indexing="ij")

n_steps = 80
ramp_up, plateau, ramp_down = 10, 60, 10
amplitude = torch.cat(
    [
        torch.linspace(0.0, 1.0, ramp_up),
        torch.ones(plateau),
        torch.linspace(1.0, 0.0, ramp_down),
    ]
)
assert amplitude.shape[0] == n_steps

bump = gaussian_pressure_torch(xx, yy, center_x=0.0, center_y=0.0, amplitude=1.0, sigma=0.3)
stimulus = amplitude[:, None, None] * bump[None, :, :]  # [time, H, W]
print(f"Stimulus shape: {tuple(stimulus.shape)}, peak: {stimulus.max().item():.3f}")

plt.figure(figsize=(4, 4))
plt.imshow(stimulus[n_steps // 2].numpy(), origin="lower")
plt.title("Stimulus frame at plateau")
plt.colorbar(label="amplitude")
plt.show()
# Out:
# Stimulus shape: (80, 24, 24), peak: 0.939

# %% [markdown]
# ## Step 3: Run the simulation
#
# `SimulationEngine.run()` returns one result dict per population; each carries `spikes`
# `[batch, time, N]` (a sub-step spike count per record bin -- see F-008) plus `drive`/`filtered`/
# `voltages` when `return_intermediates=True`.

# %%
results = engine.run(stimulus, return_intermediates=True)

for name, res in results.items():
    total = int(res["spikes"].sum().item())
    print(f"{name}: spikes shape {tuple(res['spikes'].shape)}, total spikes {total}")
# Out:
# SA Population: spikes shape (1, 80, 36), total spikes 9
# RA Population: spikes shape (1, 80, 64), total spikes 54

# %% [markdown]
# ## Step 4: Plot the spike rasters

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharex=True)
dt_ms = config.simulation.dt_ms

for ax, name in zip(axes, ["SA Population", "RA Population"]):
    spikes = results[name]["spikes"][0]  # [time, N]
    times, neuron_ids = torch.where(spikes > 0)
    ax.scatter(times.numpy() * dt_ms, neuron_ids.numpy(), s=4)
    ax.set_title(name)
    ax.set_xlabel("time (ms)")
ax = axes[0]
ax.set_ylabel("neuron index")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary
#
# You built a canonical `SensoryForgeConfig`, generated a Gaussian pressure stimulus, ran it through
# `SimulationEngine`, and read out spike rasters for two populations.
#
# **Next steps:**
# - Scale the grid/population sizes up (see `examples/canonical_config.yml`)
# - Try `sensoryforge run examples/canonical_config.yml --duration 1000` from the CLI for the same
#   pipeline at full size
# - See `docs/user_guide/yaml_configuration.md` and `docs/concepts/populations_and_inputs.md` for
#   multi-input populations, processing layers, and composite grids
